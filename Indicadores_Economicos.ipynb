# %% [markdown]
# #**Acompanhamento da evolução do Salário Minimo, Cesta Basica e Gasolina no período de 2000 a 2021**

# %%
# !pip install db-sqlite3
# Out:
# ...
#      |████████████████████████████████| 171 kB 5.0 MB/s
# ...
#   Created wheel for db-sqlite3: filename=db_sqlite3-0.0.1-py3-none-any.whl size=1794 sha256=0859fe323729bb99d249959e62a109a15181ed01618b9a2c8cdcc126507b2672
#   Stored in directory: /root/.cache/pip/wheels/02/38/d5/2f54461050571bf5330fee2a37ab1c9b5e7540b0572f1acdab
# ...
#   Created wheel for db: filename=db-0.1.1-py3-none-any.whl size=3895 sha256=d5d685f4ce1ed80a60cbd1e488e2236c1f3a50e96aa53017f1c2feeb8963588f
#   Stored in directory: /root/.cache/pip/wheels/8e/97/82/741d2b360507411ec233d0280d7371faa94b03bde834e4a9be
# ...
#   Created wheel for antiorm: filename=antiorm-1.2.1-py3-none-any.whl size=31679 sha256=c51c204a4521f56537417f865c4d5dbab81ea143b15995cf487313d687fcba76
#   Stored in directory: /root/.cache/pip/wheels/c5/43/70/e9729370cfff40c49d3e3d05377d54b3ecd71f64e62341ea80
# Successfully built db-sqlite3 db antiorm
# ...

# %%
import sqlite3
banco = sqlite3.connect('dados.db')
cursor = banco.cursor()

# %%
import pandas as pd
df = pd.read_sql('SELECT ano, salario_minimo, cesta_basica, gasolina FROM pesquisa', banco)
print(df)
# Out:
#      ano  salario_minimo  cesta_basica  gasolina
# 0   2000           151.0        115.38    53.040
# 1   2001           180.0        126.36    63.960
# 2   2002           200.0        137.47    62.956
# 3   2003           240.0        167.27    88.608
# 4   2004           206.0        172.37    79.252
# 5   2005           300.0        178.75    91.640
# 6   2006           350.0        176.98   103.480
# 7   2007           380.0        193.37   100.720
# 8   2008           415.0        235.87    99.720
# 9   2009           465.0        229.81   100.560
# 10  2010           510.0        247.90   103.120
# 11  2011           545.0        268.57   106.800
# 12  2012           622.0        292.84   109.600
# 13  2013           678.0        328.43   115.440
# 14  2014           724.0        344.90   119.200
# 15  2015           788.0        389.15   132.920
# 16  2016           880.0        456.47   149.200
# 17  2017           937.0        434.87   147.480
# ...

# %% [markdown]
# # EVOLUÇÃO DO SALÁRIO MINIMO, CESTA BASICA E COMBUSTIVEL
# ###### valores medios estado de SP, ref. 40 litros gasolina

# %%
df.plot(x='ano', figsize=(20,5), yticks=range(0, 1100, 100))
